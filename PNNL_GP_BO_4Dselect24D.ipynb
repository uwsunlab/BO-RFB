# %%
# Support for math
import numpy as np
import math

# Plotting tools
from matplotlib import pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings('ignore')

#File Tools for local
import pandas as pd

#Sampling
from pyDOE import lhs

# %%
import torch
from botorch.models import SingleTaskGP
from botorch.fit import fit_gpytorch_model
from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch.acquisition import qExpectedImprovement
from botorch.optim import optimize_acqf
from botorch.models.deterministic import PosteriorMeanModel
from botorch.acquisition import ExpectedImprovement
from botorch.acquisition.utils import get_infeasible_cost
from botorch.acquisition.objective import PosteriorTransform
from botorch.acquisition.analytic import UpperConfidenceBound
from botorch.acquisition import AcquisitionFunction
from botorch.acquisition.analytic import LogProbabilityOfImprovement
from botorch.acquisition.analytic import ProbabilityOfImprovement
from botorch.acquisition.analytic import PosteriorMean
from botorch.acquisition import qUpperConfidenceBound
from botorch.acquisition.active_learning import qNegIntegratedPosteriorVariance
from botorch.acquisition.active_learning import PairwiseMCPosteriorVariance

## Mixed
from gpytorch.constraints import Interval
from botorch.models import MixedSingleTaskGP
# botorch.optim.optimize.optimize_acqf_mixed
from botorch.optim import optimize_acqf_mixed

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
dtype = torch.float32
# Out:
# cpu

# %% [markdown]
# # Output

# %%
from PNNL_spectra_extract import data_102119
#data_102119.head(16)[['time','temp','analyte','yield product']]
# /Users/clarat/Documents/Sun_Lab/PNNL/PNNL_spectra_extract
# %run /Users/clarat/Documents/Sun_Lab/PNNL/PNNL_spectra_extract
# Out:
# ['102119 (1).csv', '102119 (2).csv', '102119 (3).csv', '102119 (4).csv', '102119 (5).csv', '102119 (6).csv', '102119 (7).csv', '102119 (8).csv', '102119 (9).csv', '102119 (10).csv', '102119 (11).csv', '102119 (12).csv', '102119 (13).csv', '102119 (14).csv', '102119 (15).csv', '102119 (16).csv', '102119 (17).csv', '102119 (18).csv', '102119 (19).csv', '102119 (20).csv', '102119 (21).csv', '102119 (22).csv', '102119 (23).csv', '102119 (24).csv', '102119 (25).csv', '102119 (26).csv', '102119 (27).csv', '102119 (28).csv', '102119 (29).csv', '102119 (30).csv', '102119 (31).csv', '102119 (32).csv', '102119 (33).csv', '102119 (34).csv', '102119 (35).csv', '102119 (36).csv', '102119 (37).csv', '102119 (38).csv', '102119 (39).csv', '102119 (40).csv', '102119 (41).csv', '102119 (42).csv', '102119 (43).csv', '102119 (44).csv', '102119 (45).csv', '102119 (46).csv', '102119 (47).csv', '102119 (48).csv']
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10431.50it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 14.66it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10737.99it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 66.86it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10967.91it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 66.08it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10599.76it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 92.73it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10488.58it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 34.47it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10418.29it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 90.43it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10418.63it/s]
# Deconvolving mixture: 100%|██████████| 4/4 [00:00<00:00, 130.09it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10975.23it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 67.85it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 8587.80it/s]
# Deconvolving mixture: 100%|██████████| 4/4 [00:00<00:00, 89.03it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 9617.15it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 95.76it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10336.61it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 56.94it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 9684.66it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 32.47it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 7616.34it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 80.50it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10496.68it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 96.37it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10404.24it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 70.43it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 9723.24it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 86.79it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10434.29it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 96.96it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10897.53it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 111.44it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10535.43it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 31.41it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10412.38it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 75.15it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10761.29it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 66.09it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10189.31it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 69.87it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 9125.37it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 111.33it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10432.02it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 144.27it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 7933.98it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 89.71it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10553.94it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 76.64it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10643.45it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 101.55it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10780.78it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 148.62it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10772.98it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 153.62it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10821.48it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 160.00it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10656.51it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 43.98it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10481.72it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 145.00it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10613.26it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 133.03it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10495.97it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 79.65it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10779.11it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 104.08it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10796.99it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 91.74it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10679.46it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 92.71it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10542.72it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 75.96it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10857.77it/s]
# Deconvolving mixture: 100%|██████████| 2/2 [00:00<00:00, 66.12it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10296.59it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 93.86it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10541.30it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 82.89it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10740.39it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 113.94it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10496.68it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 100.32it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10808.75it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 105.35it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10810.44it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 75.22it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10763.52it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 35.42it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10764.07it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 93.27it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 10498.27it/s]
# Deconvolving mixture: 100%|██████████| 3/3 [00:00<00:00, 73.88it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 491313.91it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 216.03it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 320487.84it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 226.56it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 266049.93it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 152.86it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 398311.85it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 188.62it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 278996.11it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 240.57it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 207006.06it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 48.04it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 235032.45it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 94.06it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 277879.63it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 157.28it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 381999.57it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 189.35it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 446075.16it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 144.41it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 473089.55it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 187.66it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 331715.13it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 170.21it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 575461.60it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 63.83it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 406869.33it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 88.75it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 115881.94it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 81.88it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 446075.16it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 87.36it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 531873.44it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 89.89it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 381067.86it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 169.04it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 498366.26it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 178.66it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 482215.51it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 129.37it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 550133.18it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 194.28it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 427171.08it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 223.51it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 382935.84it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 165.75it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 423408.74it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 17.19it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 430407.23it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 86.35it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 546286.10it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 166.41it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 145744.24it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 217.52it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 548202.89it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 127.32it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 403976.27it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 180.90it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 793085.40it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 127.78it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 445122.01it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 53.18it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 174275.32it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 60.91it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 528276.67it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 126.10it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 444805.19it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 75.31it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 593496.01it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 129.87it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 475972.05it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 166.50it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 394042.43it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 171.73it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 272904.50it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 203.24it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 272904.50it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 208.72it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 364190.73it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 172.65it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 479257.13it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 190.17it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 237895.43it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 169.84it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 176789.62it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 130.58it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 321146.61it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 229.56it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 358138.28it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 240.44it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 489773.74it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 208.77it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 505215.28it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 199.72it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 508503.90it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 207.56it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 447352.40it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 62.03it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 650990.93it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 81.91it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 319831.78it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 55.18it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 455836.10it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 98.09it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 261485.90it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 100.01it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 495207.05it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 93.16it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 468479.23it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 154.91it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 488624.94it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 78.67it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 474526.42it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 88.42it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 346425.33it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 87.76it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 292717.23it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 131.50it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 6950.62it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 64.80it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 208386.56it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 162.68it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 771544.81it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 136.98it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 482215.51it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 84.38it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 384822.23it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 92.34it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 473089.55it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 146.86it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 274945.58it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 81.65it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 409267.38it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 86.78it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 492087.63it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 15.51it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 425426.34it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 87.82it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 515636.38it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 63.45it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 488624.94it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 93.41it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 413875.03it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 224.76it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 423122.07it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 83.92it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 289866.09it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 100.70it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 362500.75it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 150.17it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 386966.75it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 271.35it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 222719.64it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 144.78it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 367834.78it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 132.26it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 340944.52it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 117.84it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 375346.12it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 309.70it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 485210.63it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 310.92it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 413875.03it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 150.06it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 301181.35it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 174.62it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 369793.67it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 141.86it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 324650.02it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 93.79it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 417190.45it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 92.64it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 204366.02it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 28.62it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 431000.89it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 61.25it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 600914.71it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 99.72it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 472731.69it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 144.59it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 510581.12it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 358755.05it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 95.36it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 395038.75it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 165.45it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 493252.80it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 67.25it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 493252.80it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 14.35it/s]
# Performing baseline correction: 100%|██████████| 149/149 [00:00<00:00, 489007.27it/s]
# Deconvolving mixture: 100%|██████████| 1/1 [00:00<00:00, 98.46it/s]

# %%
avg_data = data_102119.groupby('time').mean().reset_index()[['time','temp','sulf','analyte','yield product']]
avg_data
# Out:
#     time   temp  sulf  analyte  yield product
# 0     49   45.0  89.0     84.0       0.009903
# 1     87   95.0  95.0     97.0       0.103900
# 2    125   95.0  80.0     39.0       0.033182
# 3    163  145.0  90.0     57.0       0.777693
# 4    201  145.0  75.0     79.0       0.025126
# 5    239   95.0  82.0     62.0       0.027045
# 6    277   45.0  77.0     93.0       0.015058
# 7    315   95.0  92.0     75.0       0.303520
# 8    353  145.0  94.0     66.0       0.972973
# 9    391  145.0  97.0     35.0       0.974877
# 10   429   45.0  84.0     48.0       0.022536
# 11   466   45.0  85.0     70.0       0.014281
# 12   505   45.0  99.0     53.0       0.031316
# 13   543  145.0  79.0     88.0       0.207730
# 14   581   95.0  87.0     44.0       0.164975

# %%
std_data = data_102119.groupby('time').std().reset_index()[['time','temp','sulf','analyte','yield product']]
std_data
# Out:
#     time  temp  sulf  analyte  yield product
# 0     49   0.0   0.0      0.0       0.002110
# 1     87   0.0   0.0      0.0       0.007884
# 2    125   0.0   0.0      0.0       0.011663
# 3    163   0.0   0.0      0.0       0.142828
# 4    201   0.0   0.0      0.0       0.008250
# 5    239   0.0   0.0      0.0       0.010353
# 6    277   0.0   0.0      0.0       0.005608
# 7    315   0.0   0.0      0.0       0.025185
# 8    353   0.0   0.0      0.0       0.001016
# 9    391   0.0   0.0      0.0       0.000763
# 10   429   0.0   0.0      0.0       0.010566
# 11   466   0.0   0.0      0.0       0.007390
# 12   505   0.0   0.0      0.0       0.010028
# 13   543   0.0   0.0      0.0       0.102047
# 14   581   0.0   0.0      0.0       0.020561

# %% [markdown]
# # Split the data

# %%
x1 = torch.tensor([avg_data['time'],avg_data['temp'],avg_data['sulf'],avg_data['analyte']],dtype=torch.float32).T#[:48]
y1 = torch.tensor(avg_data['yield product'],dtype=torch.float32).reshape(-1,1)

# %% [markdown]
# # 4D BO to determine temps

# %%
#bounds = torch.tensor([[30., 20., 75. , 33.], [600., 170., 100.,100.]], dtype=dtype, device=device)
bounds = torch.tensor([[avg_data['time'].min(),avg_data['temp'].min(),avg_data['sulf'].min() , avg_data['analyte'].min()], [avg_data['time'].max(), avg_data['temp'].max(), avg_data['sulf'].max() , avg_data['analyte'].max()]], dtype=dtype, device=device)
#bounds = torch.tensor([[0,70,100], [80,105,150]], dtype=dtype, device=device)
#bounds = torch.tensor([[0], [150]], dtype=dtype, device=device)
#[75.0, 100.0], [33.0, 100.0],[20.0,170.0],[30.0,600.0]
batch_size = 3 #train_size

# For EI 
best_f = torch.tensor(1 ,dtype=dtype) 
target_vector = torch.tensor([1],dtype=dtype) # target is 95% or highers

# %%
train_x = torch.tensor(x1, dtype=dtype).to(device=device, dtype=dtype)
train_y = torch.tensor(y1, dtype=dtype)
#train_x,train_y

# %%
gp_model = SingleTaskGP(train_x, train_y).to(device=device, dtype=dtype)
mll = ExactMarginalLogLikelihood(gp_model.likelihood, gp_model)
fit_gpytorch_model(mll)
# Out:
# ExactMarginalLogLikelihood(
#   (likelihood): GaussianLikelihood(
#     (noise_covar): HomoskedasticNoise(
#       (noise_prior): GammaPrior()
#       (raw_noise_constraint): GreaterThan(1.000E-04)
#     )
#   )
#   (model): SingleTaskGP(
#     (likelihood): GaussianLikelihood(
#       (noise_covar): HomoskedasticNoise(
#         (noise_prior): GammaPrior()
#         (raw_noise_constraint): GreaterThan(1.000E-04)
#       )
#     )
#     (mean_module): ConstantMean()
#     (covar_module): ScaleKernel(
#       (base_kernel): MaternKernel(
#         (lengthscale_prior): GammaPrior()
#         (raw_lengthscale_constraint): Positive()
#       )
#       (outputscale_prior): GammaPrior()
#       (raw_outputscale_constraint): Positive()
#     )
#   )
# )

# %%
acq_funcs = qNegIntegratedPosteriorVariance(model=gp_model, mc_points= train_x)

candidate2, _ = optimize_acqf(
    acq_function=acq_funcs,
    bounds=bounds,
    q=batch_size,
    num_restarts=1,
    raw_samples=100,
    options={"dtype": dtype, "device": device}
)

print("Centroids of Temperature Clusters:")
print(candidate2.round())
centroids = candidate2[:,1]
# Out:
# Centroids of Temperature Clusters:
# tensor([[517.,  66.,  86.,  43.],
#         [180., 120.,  77.,  38.],
#         [540.,  89.,  79.,  42.]])

# %%
old = [45,95,145]
plt.vlines(centroids,0,100, color = 'k',linestyle='dashed',alpha=0.9)
plt.vlines(old,0,100, color = 'tab:grey',linestyle='dashed',alpha=0.5)
plt.legend(['new temp line ','old temp line'])

# %% [markdown]
# # BO 4D + clustered temps

# %%
# BO parameters
batch_size = 15

# Define the bounds for continuous variables
bounds = torch.tensor([
    [30.0, 20.0, 75.0, 33.0],  # Lower bounds for the 3 continuous variables
    [600.0, 170.0,100.0, 100.0]   # Upper bounds for the 3 continuous variables
])
# xlimits = np.array([[75.0, 100.0], [33.0, 100.0],[20.0,170.0],[30.0,600.0]])

# Discrete variable choices from 1D BO
discrete_choices= centroids.numpy().T
fixed_features_list = [{1: float(discrete_choices[0])},{1: float(discrete_choices[1])},{1: float(discrete_choices[2])}]#[{0: float(choice)} for choice in discrete_choices]
fixed_features_list
# Out:
# [{1: 65.50511932373047}, {1: 119.85845184326172}, {1: 88.72348022460938}]

# %%
from botorch.models import MixedSingleTaskGP
train_X = torch.tensor(x1, dtype=dtype).to(device=device, dtype=dtype)
train_Y = torch.tensor(y1, dtype=dtype)

model = MixedSingleTaskGP(train_X, train_Y, cat_dims=[1])
mll = ExactMarginalLogLikelihood(model.likelihood, model)
fit_gpytorch_model(mll)
# Out:
# ExactMarginalLogLikelihood(
#   (likelihood): GaussianLikelihood(
#     (noise_covar): HomoskedasticNoise(
#       (noise_prior): GammaPrior()
#       (raw_noise_constraint): GreaterThan(1.000E-05)
#     )
#   )
#   (model): MixedSingleTaskGP(
#     (likelihood): GaussianLikelihood(
#       (noise_covar): HomoskedasticNoise(
#         (noise_prior): GammaPrior()
#         (raw_noise_constraint): GreaterThan(1.000E-05)
#       )
#     )
#     (mean_module): ConstantMean()
#     (covar_module): AdditiveKernel(
#       (kernels): ModuleList(
#         (0): ScaleKernel(
#           (base_kernel): AdditiveKernel(
#             (kernels): ModuleList(
#               (0): MaternKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-04)
#               )
#               (1): ScaleKernel(
#                 (base_kernel): CategoricalKernel(
#                   (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#                 )
#                 (raw_outputscale_constraint): Positive()
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#         (1): ScaleKernel(
#           (base_kernel): ProductKernel(
#             (kernels): ModuleList(
#               (0): MaternKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-04)
#               )
#               (1): CategoricalKernel(
#                 (raw_lengthscale_constraint): GreaterThan(1.000E-06)
#               )
#             )
#           )
#           (raw_outputscale_constraint): Positive()
#         )
#       )
#     )
#   )
# )

# %%
# Set of aquisition functions that can be used for mixed
qEI = qExpectedImprovement(model=model, best_f=best_f)
qUCB = qUpperConfidenceBound(model=model, beta=5) #sampler=SobolQMCNormalSampler(num_samples=15) beta = 0.1
qPV = qNegIntegratedPosteriorVariance(model=model, mc_points = x1) # This does not work for mixed...

# %%
acq_funcs = qPV

candidate1, _ = optimize_acqf(
    acq_function=acq_funcs,
    bounds=bounds,
    q=batch_size,
    num_restarts=10,
    raw_samples=100,
    options={"dtype": dtype, "device": device}
    
)

# # Choose aquisition functions
# acq_funcs = qEI

# # Re-run the BO for the mixed with constrained temps
# candidate1, _ = optimize_acqf_mixed(
#     acq_function=acq_funcs,
#     bounds=bounds,
#     q=batch_size,
#     fixed_features_list=fixed_features_list,
#     num_restarts=10,
#     raw_samples=15,
#     options={"dtype": dtype, "device": device}
# )

# %%
time = candidate1[:,0]//1
temp = candidate1[:,1]//1
sulf = candidate1[:,2]//1
anly = candidate1[:,3]//1

data = {
    'time': time,
    'temp': temp,
    'sulf': sulf,
    'anly': anly
}
df_candidate1 = pd.DataFrame(data)
df_candidate1
# Out:
#      time   temp  sulf  anly
# 0   317.0  167.0  83.0  55.0
# 1   421.0   85.0  86.0  75.0
# 2   179.0  143.0  76.0  38.0
# 3   148.0  147.0  99.0  41.0
# 4   217.0  105.0  85.0  60.0
# 5   489.0  147.0  86.0  51.0
# 6   114.0   82.0  92.0  45.0
# 7   173.0   65.0  78.0  67.0
# 8   512.0  169.0  93.0  51.0
# 9   199.0   74.0  82.0  74.0
# 10  324.0   47.0  86.0  93.0
# 11  306.0   70.0  89.0  38.0
# 12   77.0  121.0  76.0  98.0
# 13  454.0   85.0  82.0  61.0
# 14   49.0  139.0  89.0  87.0

# %%
old = [45,95,145]

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.vlines(centroids,0,600, color = 'k',linestyle='dashed',alpha=0.9)
plt.vlines(old,0,600, color = 'tab:grey',linestyle='dashed',alpha=0.5)
plt.scatter(df_candidate1['temp'],df_candidate1['time'],color = 'tab:blue')
plt.xlabel('Temperature')
plt.ylabel('Time')
plt.legend(['','new centroid','old centroid'])

plt.subplot(1,3,2)
plt.vlines(centroids,df_candidate1['sulf'].min(),df_candidate1['sulf'].max(), color = 'k',linestyle='dashed',alpha=0.9)
plt.vlines(old,df_candidate1['sulf'].min(),df_candidate1['sulf'].max(), color = 'tab:grey',linestyle='dashed',alpha=0.5)
plt.scatter(df_candidate1['temp'],df_candidate1['sulf'],color = 'tab:orange')
plt.xlabel('Temperature')
plt.ylabel('Sulfonating agent')
plt.legend(['','new centroid','old centroid'])

plt.subplot(1,3,3)
plt.vlines(centroids,df_candidate1['anly'].min(),df_candidate1['anly'].max(), color = 'k',linestyle='dashed',alpha=0.9)
plt.vlines(old,df_candidate1['anly'].min(),df_candidate1['anly'].max(), color = 'tab:grey',linestyle='dashed',alpha=0.5)
plt.scatter(df_candidate1['temp'],df_candidate1['anly'],color = 'tab:green')
plt.xlabel('Temperature')
plt.ylabel('Analyte')
plt.legend(['','new centroid','old centroid'])

# %% [markdown]
# # Projection ? (Cluster?)

# %%
temp4D = []

for i in range(candidate1.shape[0]):
    id = abs(candidate1[i,1]-centroids).argmin()
    temp4D.append(centroids[id])
temp4D =np.array(temp4D).T

# %%
old = [45,95,145]
plt.vlines(centroids,0,600, color = 'k',linestyle='dashed',alpha=0.9)
plt.vlines(old,0,600, color = 'tab:grey',linestyle='dashed',alpha=0.5)
plt.scatter(temp4D,candidate1[:,0],c=temp4D, cmap='viridis')

# %%
def contour_all(ax,data_temp,input1,input2,output,color):
    # Grab some test data.
    # X, Y, Z = axes3d.get_test_data(0.05)
    X = data_temp.sort_values(input1)[input1].to_numpy()
    Y = data_temp.sort_values(input2)[input2].to_numpy()
    X, Y = np.meshgrid(X, Y) 
    out1,out2 = data_temp.sort_values(input1)[output].to_numpy(),data_temp.sort_values(input2)[output].to_numpy() #data_temp[output].to_numpy(),data_temp[output].to_numpy()#
    Z = np.matmul(out1.reshape(len(out1),1),out2.reshape(1,len(out2)))
    #Z1,Z2 = np.meshgrid(data_temp.sort_values(input1)[output].to_numpy(), data_temp.sort_values(input2)[output].to_numpy())

    ## Plot outside 
    # fig = plt.figure()
    # ax = fig.add_subplot(projection='3d')
    ## Plot a basic wireframe.
    #ax.plot_wireframe(X, Y, Z1, rstride=10, cstride=0,color='tab:grey')
    ax.contour(X, Y, Z,8,alpha= 0.3,colors=color)
    #ax.contourf(X, Y, Z, 8, alpha=.5) # plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)
    #C = ax.contour(X, Y, Z, 8, colors='black', linewidth=.25,linstlyle = '--') # C = plt.contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
    #ax.clabel(C, inline=1, fontsize=1)


    #ax.view_init(elev=20, azim=120) 
    ax.set_xlabel(input1)
    ax.set_ylabel(input2)

# %%
fig,(ax,ax1,ax2) = plt.subplots(1, 3, figsize=(15, 5))

contour_all(ax,avg_data,'time','sulf','yield product','tab:blue')
ax.scatter(df_candidate1['time'],df_candidate1['sulf'],marker='.')

contour_all(ax1,avg_data,'time','analyte','yield product','tab:orange')
ax1.scatter(df_candidate1['time'],df_candidate1['anly'],marker='.',color='tab:orange')

contour_all(ax2,avg_data,'sulf','analyte','yield product','tab:green')
ax2.scatter(df_candidate1['sulf'],df_candidate1['anly'],marker='.',color='tab:green')
